# %% [markdown]
# # CLUSTERING USING DBSCAN

# %% [markdown]
# Density-based spatial clustering of applications with noise (DBSCAN) is commonly use algorithm of Data Mining and Machine Learning. This algorithm simply group together points that are close to each other based on a distance measurement (usually Euclidean distance) and minimum number of points.
#
# ***DBSCAN Clustering is illustrated in the figure below***
#
# <img src ="https://miro.medium.com/proxy/1*tc8UF-h0nQqUfLC8-0uInQ.gif">

# %%
#Importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.neighbors import NearestNeighbors
from sklearn import datasets


#Importing/Loading dataset
x, y = datasets.make_moons(n_samples = 2500, noise = 0.05)

x1 = x[: , 0]
x2 = x[:, 1]

#Visualization of scatter plot
plt.scatter(x1, x2, s=5)
plt.show()


#Finding an Optimal value in EPs
neigh = NearestNeighbors(n_neighbors = 2)
nbrs = neigh.fit(x)
distances, indices = nbrs.kneighbors(x)

distances = np.sort(distances, axis=0)
distances = distances[:, 1]
plt.plot(distances)

# %%
#Training the model using DBSCAN 
model = DBSCAN(eps = 0.050)
model.fit(x)
y_pred = model.labels_.astype(np.int)


#Visualization of cluster model
colors = np.array(['#00ff00','#ff0000'])
print("CLuster : \n")
plt.scatter(x1, x2, s = 5, color = colors [y_pred])
plt.show()
# Out:
# CLuster :
