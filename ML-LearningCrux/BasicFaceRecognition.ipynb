# %%
# !pip install face_recognition

#Training images
import face_recognition
import numpy as np
from PIL import Image, ImageDraw
from IPython.display import display
import cv2
import os
from datetime import datetime


#Just importing some of the images
face_1 = face_recognition.load_image_file("E:\\ML Zero to Hero\\mlzero_to_hero-main\\27_Basic_Facial_Recognition\\Faces\\elonmusk.jpg")
face_1_encoding = face_recognition.face_encodings(face_1)[0]

face_2 = face_recognition.load_image_file("E:\\ML Zero to Hero\\mlzero_to_hero-main\\27_Basic_Facial_Recognition\\Faces\\emmawatson.jpg")
face_2_encoding = face_recognition.face_encodings(face_2)[0]

face_3 = face_recognition.load_image_file("E:\\ML Zero to Hero\\mlzero_to_hero-main\\27_Basic_Facial_Recognition\\Faces\\robertdownyjr.jpg")
face_3_encoding = face_recognition.face_encodings(face_3)[0]

face_4 = face_recognition.load_image_file("E:\\ML Zero to Hero\\mlzero_to_hero-main\\27_Basic_Facial_Recognition\\Faces\\sundarpichai.jpg")
face_4_encoding = face_recognition.face_encodings(face_3)[0]

known_face_encodings = [
    face_1_encoding,
    face_2_encoding,
    face_3_encoding,
    face_4_encoding,
]
known_face_names = [
    "Elon Musk",
    "Emma Watson",
    "Robert Downy Jr.",
    "Sundar Pichai"
]

print("Done learning and creating profiles")


#Adding name to cvs files
def makeAttendanceEntry(name):
    with open("E:\\TRY_ON_VIRTUAL\\Attendance_System\\Attendance.csv",'r+') as FILE: #Opening file for reading and writing
        allLines = FILE.readlines()  # All rows will be saved in All lines
        attendanceList = []
        for line in allLines:
            entry = line.split(',')
            attendanceList.append(entry[0])
        #if name not in attendanceList:
        now = datetime.now()
        dtString = now.strftime('%d/%b/%Y, %H:%M:%S')
        FILE.writelines(f'\n{name},{dtString}')
        
file_name = "E:\\ML Zero to Hero\\mlzero_to_hero-main\\27_Basic_Facial_Recognition\\Faces\\Unknowns\\unkown02.jpg"
unknown_image = face_recognition.load_image_file(file_name)
unknown_image_to_draw = cv2.imread(file_name)

face_locations = face_recognition.face_locations(unknown_image)
face_encodings = face_recognition.face_encodings(unknown_image, face_locations)

pil_image = Image.fromarray(unknown_image)
draw = ImageDraw.Draw(pil_image)

for (top, right, bottom, left), face_encoding in zip(face_locations, face_encodings):
    # See if the face is a match for the known face(s)
    matches = face_recognition.compare_faces(known_face_encodings, face_encoding)

    name = "Unknown"

    face_distances = face_recognition.face_distance(known_face_encodings, face_encoding)
    best_match_index = np.argmin(face_distances)
    if matches[best_match_index]:
        name = known_face_names[best_match_index]

    # Draw a box around the face using the Pillow module
    cv2.rectangle(unknown_image_to_draw,(left, top), (right, bottom), (0,255,0),3 )
    draw.rectangle(((left, top), (right, bottom)), outline=(0, 255, 255))
    cv2.putText(unknown_image_to_draw,name,(left,top-20), cv2.FONT_HERSHEY_SIMPLEX,1, (0,0,255), 2,cv2.LINE_AA)
    print(name)
    makeAttendanceEntry(name)

# display(pil_image)
cv2.imshow("Result", unknown_image_to_draw)


#Exploring csv file


import pandas as pd
sheet = pd.read_csv("E:\\TRY_ON_VIRTUAL\\Attendance_System\\Attendance.csv", header=None)
sheet.columns = ["Names", "Date", "Time"]
sheet.head()
# Out:
# ...
# WARNING: You are using pip version 20.2.3; however, version 20.2.4 is available.
# You should consider upgrading via the 'c:\users\dell\anaconda3\python.exe -m pip install --upgrade pip' command.
# Done learning and creating profiles
# Emma Watson
#          Names         Date       Time
# 0  Emma Watson  07/Nov/2020   07:40:56
# 1  Emma Watson  07/Nov/2020   07:43:50
# 2  Emma Watson  07/Nov/2020   07:44:26
# 3  Emma Watson  07/Nov/2020   07:45:01
# 4  Emma Watson  07/Nov/2020   07:46:18
